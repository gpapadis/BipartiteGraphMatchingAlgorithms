# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

main_dir = 'C:\\Users\\Georgios\\Downloads\\clustering4ccerRevision\\journal\\new\\'
df = pd.read_csv(main_dir + 'schemaAgnosticEmbeddingsAnalysisFinalTimes.csv', sep='|')
df
# Out:
#                    Dataset  Valid Pairs  Unnamed: 2  CNC F-Measure  \
# 0              Restaurants       764784       1.000          0.581
# 1              Restaurants       764784       1.000          0.566
# 2                  Abt-Buy      1157776       1.000          0.095
# 3                  Abt-Buy      1157776       1.000          0.083
# 4   Amazon-Google Products      4114806       1.000          0.146
# 5   Amazon-Google Products      4114806       1.000          0.139
# 6                 DBLP-ACM      6001104       1.000          0.831
# 7                 DBLP-ACM      6001104       1.000          0.847
# 8                 DBLP-ACM      6001104       1.000          0.117
# 9                 DBLP-ACM      6001104       1.000          0.167
# 10               IMDB-TMDB     30280972       0.977          0.658
# 11               IMDB-TMDB     30994608       1.000          0.438
# 12               IMDB-TVDB     39651396       0.992          0.402
# 13               IMDB-TVDB     39971580       1.000          0.116
# 14               TMDB-TVDB     45903992       0.971          0.499
# 15               TMDB-TVDB     47297360       1.000          0.562
# 16               TMDB-TVDB     47297360       1.000          0.000
# 17               TMDB-TVDB     47139111       0.997          0.253
# 18               TMDB-TVDB     47297360       1.000          0.206
# 19            DBLP-Scholar    154364148       1.000          0.473
# 20            DBLP-Scholar    154364148       1.000          0.370
#
#     CNC Threshold  CNC Run-time  RSR F-Measure  RSR Threshold  RSR Run-time  \
# 0            0.95            11          0.601           0.95            51
# 1            0.65             6          0.584           0.80            11
# 2            0.90             9          0.194           0.85            73
# 3            0.55            10          0.139           0.60            42
# 4            0.95            29          0.188           0.95            49
# 5            0.65            31          0.159           0.65            36
# 6            0.95            41          0.873           0.90            59
# 7            0.60            40          0.866           0.50            64
# 8            0.95            41          0.136           0.95            84
# 9            0.35            39          0.181           0.35            54
# 10           0.85           195          0.646           0.85           269
# 11           0.50           203          0.463           0.55           292
# 12           0.85           249          0.366           0.85           330
# 13           0.40           723          0.117           0.45           313
# 14           0.95           311          0.418           0.95           443
# 15           0.75           310          0.563           0.85           366
# 16           0.00          9389          0.012           0.95          3382
# 17           0.95           306          0.217           0.95           778
# 18           0.10           305          0.199           0.10           370
# 19           0.90          1100          0.497           0.90          1384
# 20           0.55           991          0.422           0.55          1321
#
#     RCA F-Measure  ...  BMC Run-time  EXC F-Measure  EXC Threshold  \
# 0           0.606  ...            11          0.629           0.95
# 1           0.626  ...             7          0.626           0.65
# 2           0.337  ...            48          0.244           0.80
# 3           0.297  ...            91          0.205           0.45
# 4           0.221  ...            39          0.251           0.90
# 5           0.214  ...            39          0.254           0.50
# 6           0.889  ...            58          0.931           0.90
# 7           0.868  ...            87          0.929           0.55
# 8           0.174  ...            59          0.239           0.95
# 9           0.183  ...            58          0.241           0.25
# 10          0.507  ...           217          0.689           0.85
# 11          0.413  ...           243          0.629           0.40
# 12          0.335  ...           369          0.464           0.85
# 13          0.169  ...           951          0.297           0.35
# 14          0.374  ...           306          0.614           0.85
# 15          0.440  ...           314          0.574           0.60
# 16          0.067  ...         13004          0.367           0.95
# 17          0.203  ...           299          0.320           0.95
# 18          0.149  ...           444          0.321           0.05
# 19          0.683  ...          1458          0.717           0.80
# 20          0.642  ...          1257          0.664           0.45
#
#     EXC Run-time  KRC F-Measure  KRC Threshold  KRC Run-time  UMC F-Measure  \
# 0             11          0.630           0.95           108          0.637
# 1              8          0.647           0.65            37          0.656
# 2             59          0.338           0.80           152          0.424
# 3            101          0.302           0.45           278          0.393
# 4            140          0.316           0.65          2451          0.267
# 5            500          0.307           0.40          2496          0.254
# 6             50          0.965           0.70          3737          0.967
# 7             55          0.966           0.45          2174          0.960
# 8             46          0.308           0.80          2568          0.284
# 9             63          0.304           0.25           345          0.292
# 10           233          0.693           0.80          1239          0.689
# 11           801          0.667           0.40          2425          0.625
# 12           277          0.488           0.85          1791          0.487
# 13          1829          0.344           0.35          5335          0.250
# 14           774          0.600           0.85          2710          0.537
# 15           468          0.560           0.85          1802          0.560
# 16         12952          0.340           0.95         26403          0.175
# 17           397          0.312           0.95          1851          0.292
# 18           388          0.300           0.05          2014          0.243
# 19         16429          0.738           0.80         33376          0.704
# 20         32055          0.704           0.45         59005          0.664
#
#     UMC Threshold  UMC Run-time
# 0            0.95            15
# 1            0.65             8
# 2            0.80           124
# 3            0.40           918
# 4            0.80          3436
# 5            0.40          5521
# 6            0.85           335
# 7            0.50           481
# 8            0.95            67
# 9            0.25           115
# 10           0.85           314
# 11           0.45           568
# 12           0.85           449
# 13           0.35          7353
# 14           0.95           462
# 15           0.85           457
# 16           0.95         73832
# 17           0.95           566
# 18           0.05           615
# 19           0.85          3586
# 20           0.50          6068
#
# [21 rows x 27 columns]

# %%
runtimes = pd.DataFrame()
runtimes['Dataset'] = df['Dataset']

for column in df:
    if (0 < column.find('Run-time')):
#         if (column.find('BAH') < 0):
        runtimes[column] = df[column]

runtimes.columns = ['Dataset', 'CNC', 'RSR', 'RCA', 'BAH', 'BMC', 'EXC', 'KRC',  'UMC']

# %%
runtimes
# Out:
#                    Dataset   CNC   RSR   RCA     BAH    BMC    EXC    KRC  \
# 0              Restaurants    11    51    18    1972     11     11    108
# 1              Restaurants     6    11     9    1871      7      8     37
# 2                  Abt-Buy     9    73    24    1082     48     59    152
# 3                  Abt-Buy    10    42    22    1088     91    101    278
# 4   Amazon-Google Products    29    49    89    2141     39    140   2451
# 5   Amazon-Google Products    31    36    94    2146     39    500   2496
# 6                 DBLP-ACM    41    59   140    2025     58     50   3737
# 7                 DBLP-ACM    40    64   144    2010     87     55   2174
# 8                 DBLP-ACM    41    84   171    2011     59     46   2568
# 9                 DBLP-ACM    39    54   135    2068     58     63    345
# 10               IMDB-TMDB   195   269   716    2845    217    233   1239
# 11               IMDB-TMDB   203   292   685    2835    243    801   2425
# 12               IMDB-TVDB   249   330   778    3276    369    277   1791
# 13               IMDB-TVDB   723   313   854    3059    951   1829   5335
# 14               TMDB-TVDB   311   443  1288    3199    306    774   2710
# 15               TMDB-TVDB   310   366  1045    3142    314    468   1802
# 16               TMDB-TVDB  9389  3382  1346    3530  13004  12952  26403
# 17               TMDB-TVDB   306   778  1306    3595    299    397   1851
# 18               TMDB-TVDB   305   370  1138    3118    444    388   2014
# 19            DBLP-Scholar  1100  1384  2287  146283   1458  16429  33376
# 20            DBLP-Scholar   991  1321  1799  150925   1257  32055  59005
#
#       UMC
# 0      15
# 1       8
# 2     124
# 3     918
# 4    3436
# 5    5521
# 6     335
# 7     481
# 8      67
# 9     115
# 10    314
# 11    568
# 12    449
# 13   7353
# 14    462
# 15    457
# 16  73832
# 17    566
# 18    615
# 19   3586
# 20   6068

# %%
datasets = ['Restaurants', 'Abt-Buy', 'Amazon-Google Products', 'DBLP-ACM', 'IMDB-TMDB', 
            'IMDB-TVDB', 'TMDB-TVDB', 'Walmart-Amazon', 'DBLP-Scholar', 'Movies']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale = 1.4)
sns.set_style("white")

# %%
dataset_df = runtimes[runtimes['Dataset']==datasets[0]]
p = sns.boxplot(data = dataset_df,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"})
p.set_title("Schema-Agnostic Semantic Weights", fontsize = 25)
plt.suptitle('D_RE',  y=0.85)
plt.ylim(0, 160)
plt.savefig(main_dir + 'saseD1RT.eps', format='eps')

# %%
dataset_df = runtimes[runtimes['Dataset']==datasets[1]]
p = sns.boxplot(data = dataset_df,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"})
plt.suptitle('D_AB',  y=0.85)
plt.ylim(0, 1000)
plt.savefig(main_dir + 'saseD2RT.eps', format='eps')

# %%
dataset_df = runtimes[runtimes['Dataset']==datasets[2]]
p = sns.boxplot(data = dataset_df,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"})
plt.suptitle('D_AG',  y=0.85)
plt.ylim(0, 6000)
plt.savefig(main_dir + 'saseD3RT.eps', format='eps')

# %%
dataset_df = runtimes[runtimes['Dataset']==datasets[3]]
p = sns.boxplot(data = dataset_df,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"})
plt.suptitle('D_DA',  y=0.85)
plt.ylim(0, 4000)
plt.savefig(main_dir + 'saseD4RT.eps', format='eps')

# %%
dataset_df = runtimes[runtimes['Dataset']==datasets[4]]
p = sns.boxplot(data = dataset_df,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"})
plt.suptitle('D_IM',  y=0.85)
plt.ylim(0, 2500)
plt.savefig(main_dir + 'saseD5RT.eps', format='eps')

# %%
dataset_df = runtimes[runtimes['Dataset']==datasets[5]]
p = sns.boxplot(data = dataset_df,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"})
p.set_title("Schema-Agnostic Semantic Weights", fontsize = 25)
plt.suptitle('D_IT',  y=0.85)
plt.ylim(0, 7500)
plt.savefig(main_dir + 'saseD6RT.eps', format='eps')

# %%
dataset_df = runtimes[runtimes['Dataset']==datasets[6]]
p = sns.boxplot(data = dataset_df,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"})
plt.suptitle('D_MT',  y=0.85)
plt.ylim(0, 14000)
plt.savefig(main_dir + 'saseD7RT.eps', format='eps')

# %%
dataset_df = runtimes[runtimes['Dataset']==datasets[7]]
dataset_df.drop('Dataset', axis=1, inplace=True)
p = sns.boxplot(data = dataset_df,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"})
plt.suptitle('D_WA',  y=0.85)
plt.ylim(0, 10000)
plt.savefig(main_dir + 'saseD8RT.eps', format='eps')
# Out:
# C:\Users\Georgios\Anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dataset_df = runtimes[runtimes['Dataset']==datasets[8]]
p = sns.boxplot(data = dataset_df,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"})
plt.suptitle('D_DS',  y=0.85)
plt.ylim(0, 60000)
plt.savefig(main_dir + 'saseD9RT.eps', format='eps')

# %%
dataset_df = runtimes[runtimes['Dataset']==datasets[9]]
dataset_df.drop('Dataset', axis=1, inplace=True)
p = sns.boxplot(data = dataset_df,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"})
plt.suptitle('D_ID',  y=0.85)
plt.ylim(0, 2800000)
plt.savefig(main_dir + 'saseD10RT.eps', format='eps')

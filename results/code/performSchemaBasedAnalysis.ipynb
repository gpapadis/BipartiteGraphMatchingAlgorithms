# %%
import pandas as pd

df = pd.read_excel('C:\\Users\\Georgios\\Downloads\\clustering\\schemaBasedAnalysisClean.xlsx')
df
# Out:
#          Dataset Attribute Name          Similarity Measure Duplicates Type  \
# 0    Restaurants           Name           Cosine Similarity          Scarce
# 1    Restaurants           Name         Damerau Levenshtein          Scarce
# 2    Restaurants           Name          Euclidean Distance          Scarce
# 3    Restaurants           Name         Generalized Jaccard          Scarce
# 4    Restaurants           Name             Jaro Similarity          Scarce
# ..           ...            ...                         ...             ...
# 202       Movies          Title         Overlap Coefficient        Balanced
# 203       Movies          Title            q-grams Distance        Balanced
# 204       Movies          Title                 Simon White        Balanced
# 205       Movies          Title  Longest Common Subsequence        Balanced
# 206       Movies          Title    Longest Common Substring        Balanced
#
#      Valid Pairs       Domain  Average Characters D1  Average Tokens D1  \
# 0           2210  Restaurants                     11                  2
# 1         292737  Restaurants                     11                  2
# 2         286463  Restaurants                     11                  2
# 3           2210  Restaurants                     11                  2
# 4         318143  Restaurants                     11                  2
# ..           ...          ...                    ...                ...
# 202     18961432       Movies                     18                  3
# 203     76181835       Movies                     18                  3
# 204    155889165       Movies                     18                  3
# 205    373359861       Movies                     18                  3
# 206    373359861       Movies                     18                  3
#
#      Coverage D1  Average Characters D2  ...  KRC Recall  KRC F-Measure  \
# 0           0.67                     11  ...    0.977528       0.844660
# 1           0.67                     11  ...    0.786517       0.786517
# 2           0.67                     11  ...    0.910112       0.835052
# 3           0.67                     11  ...    0.966292       0.834951
# 4           0.67                     11  ...    0.898876       0.820513
# ..           ...                    ...  ...         ...            ...
# 202         1.00                     24  ...    0.395486       0.542184
# 203         1.00                     24  ...    0.513056       0.654667
# 204         1.00                     24  ...    0.517999       0.659961
# 205         1.00                     24  ...    0.462713       0.601165
# 206         1.00                     24  ...    0.476972       0.617253
#
#      KRC Threshold KRC Run-time  UMC Precision UMC Recall  UMC F-Measure  \
# 0             0.50          6.2       0.739130   0.955056       0.833333
# 1             0.80         39.9       0.786517   0.786517       0.786517
# 2             0.65         21.0       0.729730   0.910112       0.810000
# 3             0.25          2.0       0.730435   0.943820       0.823529
# 4             0.80         20.3       0.736364   0.910112       0.814070
# ..             ...          ...            ...        ...            ...
# 202           0.55       1167.3       0.780069   0.415300       0.542029
# 203           0.25       5019.3       0.878116   0.514587       0.648906
# 204           0.40       8523.7       0.896167   0.520579       0.658588
# 205           0.10     540163.7       0.760942   0.469186       0.580465
# 206           0.20      21978.6       0.834371   0.480558       0.609864
#
#      UMC Threshold  UMC Run-time  BMC Configuration
# 0             0.60           6.3              Right
# 1             0.80          10.4              Right
# 2             0.60          10.6              Right
# 3             0.40           0.9              Right
# 4             0.80           5.6              Right
# ..             ...           ...                ...
# 202           0.55         305.3              Right
# 203           0.35        1125.6              Right
# 204           0.50        2509.7              Right
# 205           0.40        5929.1              Right
# 206           0.35        5858.7              Right
#
# [207 rows x 58 columns]

# %%
for index, row in df.iterrows():
    if (row['Positive P-value'] < 0.005):
        df.loc[index, 'Positive Distribution'] = 'unknown'
    if (row['Negative P-value'] < 0.005):
        df.loc[index, 'Negative Distribution'] = 'unknown'
df.drop(columns=['Positive P-value', 'Negative P-value'], inplace=True)
df
# Out:
#          Dataset Attribute Name          Similarity Measure Duplicates Type  \
# 0    Restaurants           Name           Cosine Similarity          Scarce
# 1    Restaurants           Name         Damerau Levenshtein          Scarce
# 2    Restaurants           Name          Euclidean Distance          Scarce
# 3    Restaurants           Name         Generalized Jaccard          Scarce
# 4    Restaurants           Name             Jaro Similarity          Scarce
# ..           ...            ...                         ...             ...
# 202       Movies          Title         Overlap Coefficient        Balanced
# 203       Movies          Title            q-grams Distance        Balanced
# 204       Movies          Title                 Simon White        Balanced
# 205       Movies          Title  Longest Common Subsequence        Balanced
# 206       Movies          Title    Longest Common Substring        Balanced
#
#      Valid Pairs       Domain  Average Characters D1  Average Tokens D1  \
# 0           2210  Restaurants                     11                  2
# 1         292737  Restaurants                     11                  2
# 2         286463  Restaurants                     11                  2
# 3           2210  Restaurants                     11                  2
# 4         318143  Restaurants                     11                  2
# ..           ...          ...                    ...                ...
# 202     18961432       Movies                     18                  3
# 203     76181835       Movies                     18                  3
# 204    155889165       Movies                     18                  3
# 205    373359861       Movies                     18                  3
# 206    373359861       Movies                     18                  3
#
#      Coverage D1  Average Characters D2  ...  KRC Recall  KRC F-Measure  \
# 0           0.67                     11  ...    0.977528       0.844660
# 1           0.67                     11  ...    0.786517       0.786517
# 2           0.67                     11  ...    0.910112       0.835052
# 3           0.67                     11  ...    0.966292       0.834951
# 4           0.67                     11  ...    0.898876       0.820513
# ..           ...                    ...  ...         ...            ...
# 202         1.00                     24  ...    0.395486       0.542184
# 203         1.00                     24  ...    0.513056       0.654667
# 204         1.00                     24  ...    0.517999       0.659961
# 205         1.00                     24  ...    0.462713       0.601165
# 206         1.00                     24  ...    0.476972       0.617253
#
#      KRC Threshold KRC Run-time UMC Precision  UMC Recall  UMC F-Measure  \
# 0             0.50          6.2      0.739130    0.955056       0.833333
# 1             0.80         39.9      0.786517    0.786517       0.786517
# 2             0.65         21.0      0.729730    0.910112       0.810000
# 3             0.25          2.0      0.730435    0.943820       0.823529
# 4             0.80         20.3      0.736364    0.910112       0.814070
# ..             ...          ...           ...         ...            ...
# 202           0.55       1167.3      0.780069    0.415300       0.542029
# 203           0.25       5019.3      0.878116    0.514587       0.648906
# 204           0.40       8523.7      0.896167    0.520579       0.658588
# 205           0.10     540163.7      0.760942    0.469186       0.580465
# 206           0.20      21978.6      0.834371    0.480558       0.609864
#
#      UMC Threshold  UMC Run-time  BMC Configuration
# 0             0.60           6.3              Right
# 1             0.80          10.4              Right
# 2             0.60          10.6              Right
# 3             0.40           0.9              Right
# 4             0.80           5.6              Right
# ..             ...           ...                ...
# 202           0.55         305.3              Right
# 203           0.35        1125.6              Right
# 204           0.50        2509.7              Right
# 205           0.40        5929.1              Right
# 206           0.35        5858.7              Right
#
# [207 rows x 56 columns]

# %%
df['Positive Distribution'].value_counts()
# Out:
# unknown         168
# johnsonsb         5
# johnsonsu         5
# powernorm         4
# weibull_min       4
# burr12            3
# triang            3
# exponnorm         2
# dweibull          2
# gennorm           1
# weibull_max       1
# genlogistic       1
# t                 1
# norminvgauss      1
# chi               1
# exponpow          1
# gausshyper        1
# powerlognorm      1
# hypsecant         1
# gengamma          1
# Name: Positive Distribution, dtype: int64

# %%
df['Negative Distribution'].value_counts()
# Out:
# unknown        179
# burr12           5
# johnsonsu        5
# mielke           4
# burr             3
# exponweib        2
# gennorm          2
# betaprime        1
# gengamma         1
# genextreme       1
# dweibull         1
# invweibull       1
# genlogistic      1
# invgauss         1
# Name: Negative Distribution, dtype: int64

# %%
df['Dataset'].value_counts()
# Out:
# DBLP-ACM                  27
# TMDB-TVDB                 26
# Walmart-Amazon            26
# IMDB-TVDB                 25
# IMDB-TMDB                 24
# DBLP-Scholar              20
# Restaurants               20
# Amazon-Google Products    14
# Movies                    13
# Abt-Buy                   12
# Name: Dataset, dtype: int64

# %%
df.groupby(['Dataset'])['Valid Pairs'].mean()
# Out:
# Dataset
# Abt-Buy                   1.048049e+06
# Amazon-Google Products    2.898687e+06
# DBLP-ACM                  4.486294e+06
# DBLP-Scholar              1.191785e+08
# IMDB-TMDB                 5.807344e+06
# IMDB-TVDB                 8.388741e+06
# Movies                    2.507272e+08
# Restaurants               1.622398e+05
# TMDB-TVDB                 2.802875e+06
# Walmart-Amazon            2.809570e+07
# Name: Valid Pairs, dtype: float64

# %%
fMeasures = pd.DataFrame()
for column in df:
    if (0 < column.find('F-Measure')):
            fMeasures[column] = df[column]

# %%
precision = pd.DataFrame()
for column in df:
    if (0 < column.find('Precision')):
            precision[column] = df[column]

# %%
recall = pd.DataFrame()
for column in df:
    if (0 < column.find('Recall')):
            recall[column] = df[column]

# %%
methods = ['CNC', 'RSR', 'RCA', 'BAH', 'BMC', 'EXC', 'KRC',  'UMC']

# %%
import seaborn as sns

precision.columns = methods
sns.boxplot(data = precision);

# %%
precision.describe().round(3)
# Out:
#            CNC      RSR      RCA      BAH      BMC      EXC      KRC      UMC
# count  207.000  207.000  207.000  207.000  207.000  207.000  207.000  207.000
# mean     0.833    0.708    0.671    0.640    0.703    0.771    0.744    0.709
# std      0.153    0.202    0.196    0.218    0.185    0.184    0.183    0.184
# min      0.367    0.194    0.230    0.030    0.230    0.302    0.276    0.245
# 25%      0.742    0.548    0.523    0.473    0.554    0.629    0.617    0.563
# 50%      0.841    0.745    0.699    0.651    0.734    0.819    0.790    0.750
# 75%      0.982    0.878    0.832    0.815    0.840    0.944    0.907    0.848
# max      1.000    0.976    0.980    0.981    0.983    0.997    0.991    0.983

# %%
recall.columns = methods
sns.boxplot(data = recall);

# %%
recall.describe().round(3)
# Out:
#            CNC      RSR      RCA      BAH      BMC      EXC      KRC      UMC
# count  207.000  207.000  207.000  207.000  207.000  207.000  207.000  207.000
# mean     0.434    0.478    0.467    0.363    0.551    0.518    0.552    0.585
# std      0.217    0.199    0.216    0.272    0.189    0.197    0.192    0.193
# min      0.026    0.103    0.095    0.023    0.176    0.068    0.069    0.180
# 25%      0.257    0.362    0.293    0.158    0.418    0.393    0.436    0.439
# 50%      0.425    0.454    0.389    0.221    0.523    0.474    0.523    0.538
# 75%      0.544    0.588    0.614    0.602    0.634    0.607    0.634    0.704
# max      0.915    0.939    0.934    0.931    0.974    0.966    0.978    0.980

# %%
fMeasures.columns = methods
sns.boxplot(data = fMeasures);

# %%
fMeasures.describe().round(3)
# Out:
#            CNC      RSR      RCA      BAH      BMC      EXC      KRC      UMC
# count  207.000  207.000  207.000  207.000  207.000  207.000  207.000  207.000
# mean     0.539    0.554    0.527    0.418    0.603    0.599    0.618    0.627
# std      0.199    0.181    0.182    0.243    0.161    0.167    0.165    0.163
# min      0.050    0.155    0.149    0.031    0.251    0.124    0.126    0.251
# 25%      0.404    0.434    0.416    0.245    0.531    0.511    0.548    0.562
# 50%      0.582    0.580    0.456    0.332    0.598    0.600    0.609    0.604
# 75%      0.628    0.635    0.643    0.590    0.665    0.656    0.694    0.737
# max      0.955    0.954    0.943    0.953    0.975    0.971    0.981    0.978

# %%
import pingouin  as pg

precision.rcorr()
# Out:
#        CNC    RSR    RCA    BAH    BMC    EXC    KRC  UMC
# CNC      -    ***    ***    ***    ***    ***    ***  ***
# RSR  0.783      -    ***    ***    ***    ***    ***  ***
# RCA  0.662  0.921      -    ***    ***    ***    ***  ***
# BAH   0.59  0.822  0.811      -    ***    ***    ***  ***
# BMC  0.738   0.96  0.966  0.841      -    ***    ***  ***
# EXC  0.902  0.892  0.829  0.782  0.887      -    ***  ***
# KRC  0.856  0.922  0.889  0.816  0.933  0.981      -  ***
# UMC   0.77  0.954  0.954  0.849  0.982  0.917  0.955    -
# C:\Users\Georgios\Anaconda3\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.0, the latest is 0.2.1.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
recall.rcorr()
# Out:
# C:\Users\Georgios\Anaconda3\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.8, the latest is 0.3.12.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
#        CNC    RSR    RCA    BAH    BMC    EXC    KRC  UMC
# CNC      -    ***    ***    ***    ***    ***    ***  ***
# RSR   0.96      -    ***    ***    ***    ***    ***  ***
# RCA  0.677  0.773      -    ***    ***    ***    ***  ***
# BAH  0.312  0.428  0.658      -    ***    ***    ***  ***
# BMC  0.847  0.922  0.933  0.579      -    ***    ***  ***
# EXC  0.926  0.945   0.86  0.449  0.954      -    ***  ***
# KRC  0.859  0.903  0.906  0.563  0.968   0.97      -  ***
# UMC  0.726  0.818   0.93  0.694  0.954  0.859  0.926    -

# %%
fMeasures.rcorr()
# Out:
#        CNC    RSR    RCA    BAH    BMC    EXC    KRC  UMC
# CNC      -    ***    ***    ***    ***    ***    ***  ***
# RSR  0.968      -    ***    ***    ***    ***    ***  ***
# RCA  0.767  0.829      -    ***    ***    ***    ***  ***
# BAH  0.317  0.416  0.579      -    ***    ***    ***  ***
# BMC  0.897  0.952  0.934  0.521      -    ***    ***  ***
# EXC  0.931  0.949  0.911  0.459  0.977      -    ***  ***
# KRC  0.873  0.909  0.913   0.54  0.969   0.98      -  ***
# UMC  0.802  0.879  0.919  0.617  0.969  0.925  0.958    -

# %%
fMeasures.columns = fMeasureCols
df.groupby(['Dataset'])[fMeasures.columns.tolist()].max().round(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a9684f0aca9a> in <module>
# ----> 1 fMeasures.columns = fMeasureCols
#       2 df.groupby(['Dataset'])[fMeasures.columns.tolist()].max().round(3)
#
# NameError: name 'fMeasureCols' is not defined

# %%
for index, row in df.iterrows():
    maxF1 = 0
    bestMethod = 'N/A'
    allF1s = []
    for method in methods:
        allF1s.append(row[method + ' F-Measure'])
        if (maxF1 < row[method + ' F-Measure']):
            bestMethod = method
            maxF1 = row[method + ' F-Measure']
            
    allF1s.sort()
    secondMax = allF1s[-2]
    df.loc[index, 'Top Method'] = bestMethod
    df.loc[index, 'Diff2Second'] = 1 - (secondMax / maxF1)
df

# %%
df['Top Method'].value_counts()

# %%
df.groupby(['Top Method'])['Diff2Second'].mean().round(4)*100

# %%
df.groupby(['Dataset'])['Top Method'].value_counts()

# %%
print(df.groupby(['Similarity Measure'])['Top Method'].value_counts().to_string())

# %%
df.groupby(['Duplicates Type'])['Top Method'].value_counts()

# %%
df['Duplicates Type'].value_counts()

# %%
df.groupby(['Duplicates Type', 'Top Method'])['Diff2Second'].mean().round(4)*100

# %%
from scipy.stats import pearsonr

corr, _ = pearsonr(df['UMC F-Measure'], df['UMC Threshold'])
print('Pearsons correlation: %.3f' % corr)

# %%
df['Domain'].value_counts()

# %%
df.groupby(['Domain'])['Top Method'].value_counts()
# Out:
# Domain         Top Method
# Bibliographic  KRC           27
#                UMC           16
#                EXC            5
# E-commerce     UMC           20
#                EXC           15
#                BAH            8
#                CNC            8
#                BMC            1
#                KRC            1
# Movies         KRC           42
#                UMC           20
#                EXC           12
#                CNC           10
#                BMC            3
#                RSR            1
# Restaurants    KRC            5
#                EXC            4
#                CNC            3
#                RSR            3
#                BMC            2
#                UMC            2
#                BAH            1
# Name: Top Method, dtype: int64

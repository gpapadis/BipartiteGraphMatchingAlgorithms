# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

main_dir = 'C:\\Users\\Georgios\\Downloads\\clustering4ccerRevision\\journal\\new\\'
df = pd.read_csv(main_dir + 'schemaAgnosticEmbeddingsAnalysisFinalTimesNodes.csv', sep='|')
df
# Out:
#                    Dataset  Nodes  Valid Pairs  Unnamed: 3  CNC F-Measure  \
# 0              Restaurants   2595       764784       1.000          0.581
# 1              Restaurants   2595       764784       1.000          0.566
# 2                  Abt-Buy   2152      1157776       1.000          0.095
# 3                  Abt-Buy   2152      1157776       1.000          0.083
# 4   Amazon-Google Products   4393      4114806       1.000          0.146
# 5   Amazon-Google Products   4393      4114806       1.000          0.139
# 6                 DBLP-ACM   4910      6001104       1.000          0.831
# 7                 DBLP-ACM   4910      6001104       1.000          0.847
# 8                 DBLP-ACM   4910      6001104       1.000          0.117
# 9                 DBLP-ACM   4910      6001104       1.000          0.167
# 10               IMDB-TMDB  11174     30280972       0.977          0.658
# 11               IMDB-TMDB  11174     30994608       1.000          0.438
# 12               IMDB-TVDB  12928     39651396       0.992          0.402
# 13               IMDB-TVDB  12928     39971580       1.000          0.116
# 14               TMDB-TVDB  13866     45903992       0.971          0.499
# 15               TMDB-TVDB  13866     47297360       1.000          0.562
# 16               TMDB-TVDB  13866     47297360       1.000          0.000
# 17               TMDB-TVDB  13866     47139111       0.997          0.253
# 18               TMDB-TVDB  13866     47297360       1.000          0.206
# 19            DBLP-Scholar  63869    154364148       1.000          0.473
# 20            DBLP-Scholar  63869    154364148       1.000          0.370
#
#     CNC Threshold  CNC Run-time  RSR F-Measure  RSR Threshold  RSR Run-time  \
# 0            0.95            11          0.601           0.95            51
# 1            0.65             6          0.584           0.80            11
# 2            0.90             9          0.194           0.85            73
# 3            0.55            10          0.139           0.60            42
# 4            0.95            29          0.188           0.95            49
# 5            0.65            31          0.159           0.65            36
# 6            0.95            41          0.873           0.90            59
# 7            0.60            40          0.866           0.50            64
# 8            0.95            41          0.136           0.95            84
# 9            0.35            39          0.181           0.35            54
# 10           0.85           195          0.646           0.85           269
# 11           0.50           203          0.463           0.55           292
# 12           0.85           249          0.366           0.85           330
# 13           0.40           723          0.117           0.45           313
# 14           0.95           311          0.418           0.95           443
# 15           0.75           310          0.563           0.85           366
# 16           0.00          9389          0.012           0.95          3382
# 17           0.95           306          0.217           0.95           778
# 18           0.10           305          0.199           0.10           370
# 19           0.90          1100          0.497           0.90          1384
# 20           0.55           991          0.422           0.55          1321
#
#     ...  BMC Run-time  EXC F-Measure  EXC Threshold  EXC Run-time  \
# 0   ...            11          0.629           0.95            11
# 1   ...             7          0.626           0.65             8
# 2   ...            48          0.244           0.80            59
# 3   ...            91          0.205           0.45           101
# 4   ...            39          0.251           0.90           140
# 5   ...            39          0.254           0.50           500
# 6   ...            58          0.931           0.90            50
# 7   ...            87          0.929           0.55            55
# 8   ...            59          0.239           0.95            46
# 9   ...            58          0.241           0.25            63
# 10  ...           217          0.689           0.85           233
# 11  ...           243          0.629           0.40           801
# 12  ...           369          0.464           0.85           277
# 13  ...           951          0.297           0.35          1829
# 14  ...           306          0.614           0.85           774
# 15  ...           314          0.574           0.60           468
# 16  ...         13004          0.367           0.95         12952
# 17  ...           299          0.320           0.95           397
# 18  ...           444          0.321           0.05           388
# 19  ...          1458          0.717           0.80         16429
# 20  ...          1257          0.664           0.45         32055
#
#     KRC F-Measure  KRC Threshold  KRC Run-time  UMC F-Measure  UMC Threshold  \
# 0           0.630           0.95           108          0.637           0.95
# 1           0.647           0.65            37          0.656           0.65
# 2           0.338           0.80           152          0.424           0.80
# 3           0.302           0.45           278          0.393           0.40
# 4           0.316           0.65          2451          0.267           0.80
# 5           0.307           0.40          2496          0.254           0.40
# 6           0.965           0.70          3737          0.967           0.85
# 7           0.966           0.45          2174          0.960           0.50
# 8           0.308           0.80          2568          0.284           0.95
# 9           0.304           0.25           345          0.292           0.25
# 10          0.693           0.80          1239          0.689           0.85
# 11          0.667           0.40          2425          0.625           0.45
# 12          0.488           0.85          1791          0.487           0.85
# 13          0.344           0.35          5335          0.250           0.35
# 14          0.600           0.85          2710          0.537           0.95
# 15          0.560           0.85          1802          0.560           0.85
# 16          0.340           0.95         26403          0.175           0.95
# 17          0.312           0.95          1851          0.292           0.95
# 18          0.300           0.05          2014          0.243           0.05
# 19          0.738           0.80         33376          0.704           0.85
# 20          0.704           0.45         59005          0.664           0.50
#
#     UMC Run-time
# 0             15
# 1              8
# 2            124
# 3            918
# 4           3436
# 5           5521
# 6            335
# 7            481
# 8             67
# 9            115
# 10           314
# 11           568
# 12           449
# 13          7353
# 14           462
# 15           457
# 16         73832
# 17           566
# 18           615
# 19          3586
# 20          6068
#
# [21 rows x 28 columns]

# %%
runtimes = pd.DataFrame()

for column in df:
    if (0 < column.find('Run-time')):
        runtimes[column] = df[column] / df['Valid Pairs']

runtimes.columns = ['CNC', 'RSR', 'RCA', 'BAH', 'BMC', 'EXC', 'KRC',  'UMC']

# %%
runtimes.describe().round(5)
# Out:
#             CNC       RSR       RCA       BAH       BMC       EXC       KRC  \
# count  21.00000  21.00000  21.00000  21.00000  21.00000  21.00000  21.00000
# mean    0.00002   0.00002   0.00002   0.00057   0.00003   0.00005   0.00023
# std     0.00004   0.00002   0.00000   0.00073   0.00006   0.00007   0.00022
# min     0.00001   0.00001   0.00001   0.00007   0.00001   0.00001   0.00004
# 25%     0.00001   0.00001   0.00002   0.00008   0.00001   0.00001   0.00005
# 50%     0.00001   0.00001   0.00002   0.00034   0.00001   0.00001   0.00013
# 75%     0.00001   0.00001   0.00002   0.00093   0.00001   0.00005   0.00038
# max     0.00020   0.00007   0.00003   0.00258   0.00027   0.00027   0.00062
#
#             UMC
# count  21.00000
# mean    0.00025
# std     0.00047
# min     0.00001
# 25%     0.00001
# 50%     0.00002
# 75%     0.00011
# max     0.00156

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale = 1.4)
sns.set_style("white")

# %%
p = sns.boxplot(data = runtimes,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"})
p.set_title("Schema-Agnostic Semantic Weights", fontsize = 25)
plt.ylim(0, 0.0015)
plt.savefig(main_dir + 'saseD1RT.eps', format='eps')

# %%
runtimes = pd.DataFrame()

for column in df:
    if (0 < column.find('Run-time')):
        runtimes[column] = df[column] / df['Nodes']

runtimes.columns = ['CNC', 'RSR', 'RCA', 'BAH', 'BMC', 'EXC', 'KRC',  'UMC']

# %%
runtimes.describe().round(3)
# Out:
#           CNC     RSR     RCA     BAH     BMC     EXC     KRC     UMC
# count  21.000  21.000  21.000  21.000  21.000  21.000  21.000  21.000
# mean    0.046   0.032   0.045   0.570   0.065   0.113   0.382   0.431
# std     0.145   0.050   0.031   0.605   0.201   0.221   0.433   1.166
# min     0.002   0.004   0.003   0.225   0.003   0.003   0.014   0.003
# 25%     0.007   0.013   0.021   0.254   0.012   0.013   0.129   0.033
# 50%     0.016   0.022   0.035   0.410   0.022   0.029   0.195   0.051
# 75%     0.022   0.026   0.066   0.503   0.023   0.072   0.523   0.098
# max     0.677   0.244   0.097   2.363   0.938   0.934   1.904   5.325

# %%
p = sns.boxplot(data = runtimes,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"})
p.set_title("Schema-Based Syntactic Weights", fontsize = 25)
plt.ylim(0, 2.5)
plt.savefig(main_dir + 'saseNormRT.eps', format='eps')

# %%
import pandas as pd

main_dir = 'C:\\Users\\Georgios\\Downloads\\clustering4ccerRevision\\journal\\new\\'
df = pd.read_excel(main_dir + 'schemaAgnosticEmbeddingsAnalysisClean.xlsx')
df
# Out:
#                    Dataset Embeddings  Similarity Measure Duplicates Type  \
# 0              Restaurants   FastText   Cosine Similarity          Scarce
# 1              Restaurants   FastText  Euclidean Distance          Scarce
# 2                  Abt-Buy   FastText   Cosine Similarity        Balanced
# 3                  Abt-Buy   FastText  Euclidean Distance        Balanced
# 4   Amazon-Google Products   FastText   Cosine Similarity       One-sided
# 5   Amazon-Google Products   FastText  Euclidean Distance       One-sided
# 6                 DBLP-ACM   FastText   Cosine Similarity        Balanced
# 7                 DBLP-ACM   FastText  Euclidean Distance        Balanced
# 8                 DBLP-ACM     Albert   Cosine Similarity        Balanced
# 9                 DBLP-ACM     Albert  Euclidean Distance        Balanced
# 10               IMDB-TMDB   FastText   Cosine Similarity          Scarce
# 11               IMDB-TMDB   FastText  Euclidean Distance          Scarce
# 12               IMDB-TVDB   FastText   Cosine Similarity          Scarce
# 13               IMDB-TVDB   FastText  Euclidean Distance          Scarce
# 14               TMDB-TVDB   FastText   Cosine Similarity          Scarce
# 15               TMDB-TVDB   FastText  Euclidean Distance          Scarce
# 16               TMDB-TVDB   FastText                 WMD          Scarce
# 17               TMDB-TVDB     Albert   Cosine Similarity          Scarce
# 18               TMDB-TVDB     Albert  Euclidean Distance          Scarce
# 19            DBLP-Scholar   FastText   Cosine Similarity       One-sided
# 20            DBLP-Scholar   FastText  Euclidean Distance       One-sided
#
#     Valid Pairs         Domain  Average Characters D1  Average Tokens D1  \
# 0        764784    Restaurants                    107                 21
# 1        764784    Restaurants                    107                 21
# 2       1157776     E-commerce                    307                 60
# 3       1157776     E-commerce                    307                 60
# 4       4114806     E-commerce                   1325                228
# 5       4114806     E-commerce                   1325                228
# 6       6001104  Bibliographic                    122                 21
# 7       6001104  Bibliographic                    122                 21
# 8       6001104  Bibliographic                    122                 21
# 9       6001104  Bibliographic                    122                 21
# 10     30280972         Movies                     49                  9
# 11     30994608         Movies                     49                  9
# 12     39651396         Movies                     49                  9
# 13     39971580         Movies                     49                  9
# 14     45903992         Movies                    114                 24
# 15     47297360         Movies                    114                 24
# 16     47297360         Movies                    114                 24
# 17     47139111         Movies                    114                 24
# 18     47297360         Movies                    114                 24
# 19    154364148  Bibliographic                    121                 21
# 20    154364148  Bibliographic                    121                 21
#
#     Average Characters D2  Average Tokens D2  ...  KRC Recall  KRC F-Measure  \
# 0                     111                 21  ...    0.651685       0.630435
# 1                     111                 21  ...    0.629214       0.647399
# 2                      90                 20  ...    0.228625       0.337680
# 3                      90                 20  ...    0.201673       0.301808
# 4                     259                 50  ...    0.268116       0.316070
# 5                     259                 50  ...    0.261775       0.306631
# 6                     145                 25  ...    0.946043       0.965359
# 7                     145                 25  ...    0.948291       0.966102
# 8                     145                 25  ...    0.231115       0.308153
# 9                     145                 25  ...    0.216277       0.303566
# 10                    114                 24  ...    0.669715       0.692591
# 11                    114                 24  ...    0.653963       0.666667
# 12                     94                 18  ...    0.440298       0.488360
# 13                     94                 18  ...    0.362873       0.343640
# 14                     94                 18  ...    0.740639       0.599630
# 15                     94                 18  ...    0.517808       0.560000
# 16                     94                 18  ...    0.495890       0.340119
# 17                     94                 18  ...    0.271233       0.311647
# 18                     94                 18  ...    0.312329       0.299737
# 19                    110                 20  ...    0.695407       0.737761
# 20                    110                 20  ...    0.655113       0.704402
#
#     KRC Threshold  KRC Run-time  UMC Precision  UMC Recall  UMC F-Measure  \
# 0            0.95           109       0.571429    0.719101       0.636816
# 1            0.65            43       0.628866    0.685393       0.655914
# 2            0.80           235       0.458874    0.394052       0.424000
# 3            0.45           315       0.402142    0.383829       0.392772
# 4            0.65          3717       0.246355    0.290761       0.266722
# 5            0.40          2794       0.231111    0.282609       0.254279
# 6            0.70          3821       0.965935    0.968975       0.967452
# 7            0.45          2526       0.960378    0.959083       0.959730
# 8            0.80          3874       0.511085    0.196942       0.284323
# 9            0.25           710       0.377224    0.238309       0.292091
# 10           0.80          1098       0.799731    0.604675       0.688657
# 11           0.40          2394       0.663626    0.591463       0.625470
# 12           0.85          1440       0.528962    0.451493       0.487167
# 13           0.35          5991       0.170040    0.470149       0.249752
# 14           0.85          4118       0.501188    0.578082       0.536896
# 15           0.85          1724       0.608789    0.518721       0.560158
# 16           0.95         31541       0.106128    0.501370       0.175175
# 17           0.95          1665       0.310630    0.274886       0.291667
# 18           0.05          1731       0.192021    0.329680       0.242689
# 19           0.80         41777       0.710631    0.698007       0.704262
# 20           0.45         61402       0.684622    0.644281       0.663839
#
#     UMC Threshold  UMC Run-time  BMC Configuration
# 0            0.95            40              Right
# 1            0.65             9              Right
# 2            0.80           119               Left
# 3            0.40           827               Left
# 4            0.80          2882               Left
# 5            0.40          5138               Left
# 6            0.85           316               Left
# 7            0.50           406               Left
# 8            0.95            62               Left
# 9            0.25            88               Left
# 10           0.85           318              Right
# 11           0.45           495              Right
# 12           0.85           490               Left
# 13           0.35          6877              Right
# 14           0.95           579              Right
# 15           0.85           579              Right
# 16           0.95         66543               Left
# 17           0.95           459              Right
# 18           0.05           553               Left
# 19           0.85          3264              Right
# 20           0.50          5414              Right
#
# [21 rows x 52 columns]

# %%
precision = pd.DataFrame()
for column in df:
    if (0 < column.find('Precision')):
            precision[column] = df[column]

# %%
recall = pd.DataFrame()
for column in df:
    if (0 < column.find('Recall')):
            recall[column] = df[column]

# %%
fMeasures = pd.DataFrame()
for column in df:
    if (0 < column.find('F-Measure')):
            fMeasures[column] = df[column]

# %%
fStarMeasures = pd.DataFrame()
for column in df:
    if (0 < column.find('F-Measure')):
            fStarMeasures[column] = df[column]/(2-df[column])

# %%
methods = ['CNC', 'RSR', 'RCA', 'BAH', 'BMC', 'EXC', 'KRC',  'UMC']

# %%
precision.describe().round(3)
# Out:
#        CNC Precision  RSR Precision  RCA Precision  BAH Precision  \
# count         21.000         21.000         21.000         21.000
# mean           0.742          0.524          0.431          0.410
# std            0.231          0.259          0.266          0.272
# min            0.000          0.009          0.041          0.043
# 25%            0.604          0.335          0.203          0.220
# 50%            0.745          0.536          0.404          0.444
# 75%            0.903          0.743          0.621          0.527
# max            1.000          0.971          0.936          0.977
#
#        BMC Precision  EXC Precision  KRC Precision  UMC Precision
# count         21.000         21.000         21.000         21.000
# mean           0.516          0.667          0.574          0.506
# std            0.231          0.194          0.206          0.247
# min            0.063          0.356          0.259          0.106
# 25%            0.378          0.512          0.385          0.311
# 50%            0.531          0.644          0.599          0.511
# 75%            0.661          0.791          0.680          0.664
# max            0.949          0.996          0.985          0.966

# %%
recall.describe().round(3)
# Out:
#        CNC Recall  RSR Recall  RCA Recall  BAH Recall  BMC Recall  EXC Recall  \
# count      21.000      21.000      21.000      21.000      21.000      21.000
# mean        0.274       0.317       0.394       0.312       0.448       0.420
# std         0.229       0.243       0.223       0.253       0.246       0.243
# min         0.000       0.017       0.147       0.078       0.123       0.118
# 25%         0.079       0.107       0.238       0.138       0.260       0.168
# 50%         0.229       0.284       0.312       0.179       0.407       0.395
# 75%         0.461       0.509       0.625       0.470       0.627       0.589
# max         0.735       0.793       0.846       0.888       0.916       0.874
#
#        KRC Recall  UMC Recall
# count      21.000      21.000
# mean        0.495       0.513
# std         0.240       0.218
# min         0.202       0.197
# 25%         0.268       0.330
# 50%         0.496       0.501
# 75%         0.655       0.644
# max         0.948       0.969

# %%
fMeasures.describe().round(3)
# Out:
#        CNC F-Measure  RSR F-Measure  RCA F-Measure  BAH F-Measure  \
# count         21.000         21.000         21.000         21.000
# mean           0.359          0.373          0.400          0.336
# std            0.253          0.249          0.240          0.255
# min            0.000          0.012          0.067          0.065
# 25%            0.139          0.181          0.203          0.182
# 50%            0.370          0.366          0.337          0.248
# 75%            0.562          0.563          0.606          0.470
# max            0.847          0.873          0.889          0.931
#
#        BMC F-Measure  EXC F-Measure  KRC F-Measure  UMC F-Measure
# count         21.000         21.000         21.000         21.000
# mean           0.453          0.486          0.516          0.493
# std            0.244          0.232          0.222          0.234
# min            0.105          0.205          0.300          0.175
# 25%            0.240          0.254          0.312          0.284
# 50%            0.436          0.464          0.488          0.487
# 75%            0.631          0.629          0.667          0.656
# max            0.932          0.931          0.966          0.967

# %%
fStarMeasures.describe().round(3)
# Out:
#        CNC F-Measure  RSR F-Measure  RCA F-Measure  BAH F-Measure  \
# count         21.000         21.000         21.000         21.000
# mean           0.250          0.261          0.281          0.237
# std            0.214          0.219          0.220          0.240
# min            0.000          0.006          0.035          0.034
# 25%            0.075          0.100          0.113          0.100
# 50%            0.227          0.224          0.202          0.142
# 75%            0.391          0.392          0.435          0.308
# max            0.735          0.774          0.800          0.870
#
#        BMC F-Measure  EXC F-Measure  KRC F-Measure  UMC F-Measure
# count         21.000         21.000         21.000         21.000
# mean           0.327          0.354          0.380          0.362
# std            0.234          0.230          0.235          0.240
# min            0.055          0.114          0.176          0.096
# 25%            0.136          0.145          0.185          0.166
# 50%            0.279          0.302          0.323          0.322
# 75%            0.461          0.458          0.500          0.488
# max            0.873          0.870          0.934          0.937

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale = 1.4)
sns.set_style("white")

# %%
precision.columns = methods
sns.boxplot(data = precision,
            showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"10"})
p.set_title("Precision", fontsize = 30)
plt.savefig(main_dir + 'sasePrecision.eps', format='eps')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-54714b6385a9> in <module>
# ----> 1 precision.columns = methods
#       2 sns.boxplot(data = precision,
#       3             showmeans=True,
#       4             meanprops={"marker":"o",
#       5                        "markerfacecolor":"white",
#
# NameError: name 'methods' is not defined

# %%
recall.columns = methods
sns.boxplot(data = recall,
            showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"10"})
p.set_title("Precision", fontsize = 30)
plt.savefig(main_dir + 'saseRecall.eps', format='eps')

# %%
fMeasures.columns = methods
sns.boxplot(data = fMeasures,
            showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"10"});
plt.savefig(main_dir + 'saseF1.eps', format='eps')

# %%
fStarMeasures.columns = methods
p = sns.boxplot(data = fStarMeasures,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"});
p.set(ylim=(0, 1))
plt.savefig(main_dir + 'saseFstar.eps', format='eps')

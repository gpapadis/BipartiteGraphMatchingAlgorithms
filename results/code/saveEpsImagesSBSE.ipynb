# %%
import pandas as pd

main_dir = 'C:\\Users\\Georgios\\Downloads\\clustering4ccerRevision\\journal\\new\\'
df = pd.read_excel(main_dir + 'schemaBasedEmbeddingsAnalysisClean.xlsx')
df
# Out:
#          Dataset Attribute Name Embeddings  Similarity Measure  \
# 0    Restaurants           Name   FastText   Cosine Similarity
# 1    Restaurants           Name   FastText  Euclidean Distance
# 2    Restaurants           Name   FastText                 WMD
# 3    Restaurants           Name     Albert   Cosine Similarity
# 4    Restaurants           Name     Albert  Euclidean Distance
# ..           ...            ...        ...                 ...
# 65  DBLP-Scholar          Title     Albert   Cosine Similarity
# 66  DBLP-Scholar          Title     Albert  Euclidean Distance
# 67  DBLP-Scholar          Title     Albert                 WMD
# 68        Movies          Title   FastText   Cosine Similarity
# 69        Movies          Title   FastText  Euclidean Distance
#
#    Duplicates Type  Valid Pairs         Domain  Average Characters D1  \
# 0           Scarce       339387    Restaurants                     11
# 1           Scarce       339678    Restaurants                     11
# 2           Scarce       339678    Restaurants                     11
# 3           Scarce       268054    Restaurants                     11
# 4           Scarce       339678    Restaurants                     11
# ..             ...          ...            ...                    ...
# 65       One-sided    153738496  Bibliographic                     56
# 66       One-sided    154364148  Bibliographic                     56
# 67       One-sided    154364148  Bibliographic                     56
# 68        Balanced    378388014         Movies                     18
# 69        Balanced    378631606         Movies                     18
#
#     Average Tokens D1  Coverage D1  ...  KRC Recall  KRC F-Measure  \
# 0                   2         0.67  ...    0.921348       0.803922
# 1                   2         0.67  ...    0.887640       0.818653
# 2                   2         0.67  ...    0.775281       0.644860
# 3                   2         0.67  ...    0.775281       0.704082
# 4                   2         0.67  ...    0.752809       0.779070
# ..                ...          ...  ...         ...            ...
# 65                  8         1.00  ...    0.694974       0.710678
# 66                  8         1.00  ...    0.653813       0.783286
# 67                  8         1.00  ...    0.639081       0.690382
# 68                  3         1.00  ...    0.463106       0.604407
# 69                  3         1.00  ...    0.441543       0.577121
#
#     KRC Threshold  KRC Run-time  UMC Precision  UMC Recall  UMC F-Measure  \
# 0            0.65            18       0.795455    0.786517       0.790960
# 1            0.30            18       0.802198    0.820225       0.811111
# 2            0.95            88       0.305310    0.775281       0.438095
# 3            0.95           140       0.526718    0.775281       0.627273
# 4            0.95            17       0.807229    0.752809       0.779070
# ..            ...           ...            ...         ...            ...
# 65           0.95          9589       0.686567    0.697574       0.692027
# 66           0.15          7597       0.953135    0.652080       0.774376
# 67           0.95          7541       0.729743    0.639948       0.681902
# 68           0.60         35312       0.751234    0.485807       0.590045
# 69           0.05        644820       0.638933    0.455802       0.532050
#
#     UMC Threshold  UMC Run-time  BMC Configuration
# 0            0.95            26              Right
# 1            0.40             6              Right
# 2            0.95            78              Right
# 3            0.95            67              Right
# 4            0.95             6              Right
# ..            ...           ...                ...
# 65           0.95          2489              Right
# 66           0.15          1719              Right
# 67           0.95          1729              Right
# 68           0.65          8842              Right
# 69           0.10       2053676              Right
#
# [70 rows x 59 columns]

# %%
precision = pd.DataFrame()
for column in df:
    if (0 < column.find('Precision')):
            precision[column] = df[column]

# %%
recall = pd.DataFrame()
for column in df:
    if (0 < column.find('Recall')):
            recall[column] = df[column]

# %%
fMeasures = pd.DataFrame()
for column in df:
    if (0 < column.find('F-Measure')):
            fMeasures[column] = df[column]

# %%
fStarMeasures = pd.DataFrame()
for column in df:
    if (0 < column.find('F-Measure')):
            fStarMeasures[column] = df[column]/(2-df[column])

# %%
methods = ['CNC', 'RSR', 'RCA', 'BAH', 'BMC', 'EXC', 'KRC',  'UMC']

# %%
precision.describe().round(3)
# Out:
#        CNC Precision  RSR Precision  RCA Precision  BAH Precision  \
# count         70.000         70.000         70.000         70.000
# mean           0.707          0.511          0.559          0.508
# std            0.324          0.315          0.263          0.275
# min            0.000          0.009          0.044          0.037
# 25%            0.632          0.237          0.381          0.319
# 50%            0.796          0.522          0.559          0.493
# 75%            0.965          0.811          0.797          0.783
# max            1.000          0.975          0.970          0.978
#
#        BMC Precision  EXC Precision  KRC Precision  UMC Precision
# count         70.000         70.000         70.000         70.000
# mean           0.610          0.739          0.701          0.641
# std            0.253          0.200          0.208          0.232
# min            0.051          0.229          0.203          0.101
# 25%            0.438          0.611          0.565          0.497
# 50%            0.605          0.775          0.703          0.618
# 75%            0.820          0.936          0.902          0.841
# max            0.979          0.997          0.990          0.978

# %%
recall.describe().round(3)
# Out:
#        CNC Recall  RSR Recall  RCA Recall  BAH Recall  BMC Recall  EXC Recall  \
# count      70.000      70.000      70.000      70.000      70.000      70.000
# mean        0.317       0.357       0.394       0.335       0.520       0.501
# std         0.266       0.252       0.216       0.266       0.203       0.210
# min         0.000       0.014       0.112       0.048       0.185       0.129
# 25%         0.105       0.151       0.236       0.141       0.369       0.359
# 50%         0.271       0.307       0.302       0.202       0.471       0.460
# 75%         0.477       0.480       0.525       0.518       0.651       0.630
# max         0.914       0.938       0.909       0.909       0.967       0.942
#
#        KRC Recall  UMC Recall
# count      70.000      70.000
# mean        0.554       0.562
# std         0.192       0.186
# min         0.235       0.199
# 25%         0.434       0.448
# 50%         0.481       0.485
# 75%         0.653       0.652
# max         0.966       0.977

# %%
fMeasures.describe().round(3)
# Out:
#        CNC F-Measure  RSR F-Measure  RCA F-Measure  BAH F-Measure  \
# count         70.000         70.000         70.000         70.000
# mean           0.400          0.407          0.434          0.367
# std            0.284          0.266          0.211          0.251
# min            0.000          0.011          0.069          0.053
# 25%            0.176          0.177          0.308          0.201
# 50%            0.418          0.415          0.387          0.256
# 75%            0.598          0.592          0.494          0.471
# max            0.955          0.956          0.939          0.942
#
#        BMC F-Measure  EXC F-Measure  KRC F-Measure  UMC F-Measure
# count         70.000         70.000         70.000         70.000
# mean           0.543          0.578          0.603          0.579
# std            0.207          0.190          0.176          0.187
# min            0.080          0.208          0.250          0.158
# 25%            0.413          0.438          0.506          0.449
# 50%            0.542          0.582          0.594          0.568
# 75%            0.623          0.682          0.679          0.628
# max            0.971          0.968          0.977          0.975

# %%
fStarMeasures.describe().round(3)
# Out:
#        CNC F-Measure  RSR F-Measure  RCA F-Measure  BAH F-Measure  \
# count         70.000         70.000         70.000         70.000
# mean           0.292          0.294          0.303          0.260
# std            0.248          0.238          0.203          0.235
# min            0.000          0.005          0.036          0.027
# 25%            0.096          0.097          0.182          0.112
# 50%            0.265          0.262          0.240          0.147
# 75%            0.427          0.421          0.328          0.308
# max            0.914          0.916          0.885          0.890
#
#        BMC F-Measure  EXC F-Measure  KRC F-Measure  UMC F-Measure
# count         70.000         70.000         70.000         70.000
# mean           0.402          0.433          0.456          0.433
# std            0.214          0.206          0.201          0.205
# min            0.042          0.116          0.143          0.086
# 25%            0.261          0.281          0.339          0.289
# 50%            0.372          0.410          0.422          0.396
# 75%            0.452          0.517          0.514          0.458
# max            0.944          0.938          0.955          0.950

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale = 1.4)
sns.set_style("white")

# %%
precision.columns = methods
sns.boxplot(data = precision,
            showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"10"});
plt.savefig(main_dir + 'sasePrecision.eps', format='eps')

# %%
recall.columns = methods
sns.boxplot(data = recall,
            showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"10"});
plt.savefig(main_dir + 'saseRecall.eps', format='eps')

# %%
fMeasures.columns = methods
sns.boxplot(data = fMeasures,
            showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"10"});
plt.savefig(main_dir + 'saseF1.eps', format='eps')

# %%
fStarMeasures.columns = methods
p = sns.boxplot(data = fStarMeasures,
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"10"});
p.set(ylim=(0, 1))
plt.savefig(main_dir + 'saseFstar.eps', format='eps')
